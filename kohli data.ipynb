# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt
img1=cv2.imread("C:/Users/remit/Downloads/kohli.jpg")
plt.imshow(img1[:,:,::-1])
plt.show()

# %%
result=DeepFace.analyze(img1,actions=['emotion'])
print(result)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00,  3.86it/s]
# [{'emotion': {'angry': 41.89305603504181, 'disgust': 7.132477941595994e-09, 'fear': 0.09582997299730778, 'happy': 58.00584554672241, 'sad': 0.002894217504945118, 'surprise': 4.7188416374410735e-05, 'neutral': 0.0023228292775456794}, 'dominant_emotion': 'happy', 'region': {'x': 338, 'y': 68, 'w': 95, 'h': 95}}]

# %%
result=DeepFace.analyze(img1,actions=['age'])
print(result)
# Out:
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: C:\Users\remit\.deepface\weights\age_model_weights.h5
# 100%|██████████| 539M/539M [44:12<00:00, 203kB/s]
# Action: age: 100%|██████████| 1/1 [00:00<00:00,  2.77it/s]
# [{'age': 30, 'region': {'x': 338, 'y': 68, 'w': 95, 'h': 95}}]

# %%
result=DeepFace.analyze(img1,actions=['gender'])
print(result)
# Out:
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: C:\Users\remit\.deepface\weights\gender_model_weights.h5
# 100%|██████████| 537M/537M [09:09<00:00, 977kB/s]
# Action: gender: 100%|██████████| 1/1 [00:00<00:00,  2.38it/s]
# [{'gender': {'Woman': 2.327824688563851e-06, 'Man': 100.0}, 'dominant_gender': 'Man', 'region': {'x': 338, 'y': 68, 'w': 95, 'h': 95}}]

# %%
result=DeepFace.analyze(img1,actions=['race'])
print(result)
# Out:
# Action: race: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# [{'race': {'asian': 0.018027873011305928, 'indian': 10.996314138174057, 'black': 0.2248997101560235, 'white': 4.978588595986366, 'middle eastern': 79.62372899055481, 'latino hispanic': 4.158443212509155}, 'dominant_race': 'middle eastern', 'region': {'x': 338, 'y': 68, 'w': 95, 'h': 95}}]
